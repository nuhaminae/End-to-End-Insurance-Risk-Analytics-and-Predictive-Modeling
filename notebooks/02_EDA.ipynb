# %% [markdown]
# # **Import Modules**

# %%
import os
import sys

# %%
#define path
sys.path.append(os.path.abspath(os.path.join('..')))

#import custom modules
from scripts.EDA import EDA_processor

# %% [markdown]
# # **Load DataFrame**

# %%
#define df path
processed_df_path = os.path.join(os.path.dirname(os.getcwd()), 'data/processed_insurance_data.csv')
output_folder = os.path.join(os.path.dirname(os.getcwd()), 'data')
plot_folder = os.path.join(os.path.dirname(os.getcwd()), 'plot images')

# %%
#load df
eda_processor = EDA_processor(processed_df_path, plot_folder, output_folder)
# Out:
# DataFrame loaded successfully from ..\data\processed_insurance_data.csv
#
# Imputed DataFrame Saved to: ..\data\imputed_and_processed_insurance_data.csv
#
# DataFrame Head:
#    UnderwrittenCoverID  PolicyID TransactionMonth  IsVATRegistered  \
# 0                  603        91       2013-11-01            False
# 1                  960       140       2013-11-01            False
# 2                  568        89       2013-11-01            False
# 3                  911       137       2013-11-01            False
# 4                 1106       148       2013-11-01            False
#
#     LegalType Title Language                 Bank      AccountType  \
# 0  Individual    Mr  English        Standard Bank  Current account
# 1  Individual    Mr  English        Standard Bank  Current account
# 2  Individual    Mr  English        Standard Bank  Current account
# 3  Individual    Mr  English  First National Bank  Savings account
# 4  Individual    Mr  English        Standard Bank  Current account
#
#    MaritalStatus  ...                                     ExcessSelected  \
# 0  Not specified  ...  Mobility - Taxi with value more than R100 000 ...
# 1  Not specified  ...                                          No excess
# 2  Not specified  ...                                          No excess
# 3  Not specified  ...                                          No excess
# 4  Not specified  ...                                          No excess
#
#          CoverCategory            CoverType            CoverGroup  \
# 0          Own Damage            Own Damage  Comprehensive - Taxi
# 1          Third Party          Third Party  Comprehensive - Taxi
# 2  Basic Excess Waiver  Basic Excess Waiver   Basic Excess Waiver
# 3      Keys and Alarms      Keys and Alarms  Comprehensive - Taxi
# 4      Keys and Alarms      Keys and Alarms  Comprehensive - Taxi
#
#                     Section                             Product  \
# 0       Motor Comprehensive  Mobility Commercial Cover: Monthly
# 1       Motor Comprehensive  Mobility Commercial Cover: Monthly
# 2  Optional Extended Covers  Mobility Commercial Cover: Monthly
# 3       Motor Comprehensive     Mobility Metered Taxis: Monthly
# 4       Motor Comprehensive  Mobility Commercial Cover: Monthly
#
#   StatutoryClass  StatutoryRiskType TotalPremium  TotalClaims
# 0     Commercial      IFRS Constant     7.129386  6140.350877
# 1     Commercial      IFRS Constant     7.129386  6140.350877
# 2     Commercial      IFRS Constant     2.631579  6140.350877
# 3     Commercial      IFRS Constant     7.129386  6140.350877
# 4     Commercial      IFRS Constant     1.592491  6140.350877
#
# [5 rows x 44 columns]

# %% [markdown]
# # **Detailed Exploratory Data Analysis (EDA)**

# %% [markdown]
# ## *Calculate Loss Ratio*

# %%
#call function to calculate loss
eda_processor.calculate_loss()
# Out:
# Overall Loss Ratio: 92.05
#
# Loss Ratio by Province:
#                 LossRatio
# Province
# Eastern Cape    85.149685
# Free State      90.351881
# Gauteng         93.901127
# KwaZulu-Natal   79.194306
# Limpopo         90.468752
# Mpumalanga      86.417721
# North West     102.092465
# Northern Cape  128.840435
# Western Cape    98.116633
# Loss Ratio by Vehicle Type:
#                    LossRatio
# VehicleType
# Bus                74.513390
# Heavy Commercial   95.981102
# Light Commercial   81.701411
# Medium Commercial  76.188373
# Passenger Vehicle  93.215794
# Loss Ratio by Gender:
#                 LossRatio
# Gender
# Female         136.496009
# Male           119.183089
# Not specified   91.367483

# %% [markdown]
# ## *Trends*

# %%
#call function to calculate temporal trends
eda_processor.temporal_trends()
# Out:
# Claim Frequency per month (head):
# TransactionMonth
# 2013-11-01     325
# 2013-12-01     419
# 2014-01-01     454
# 2014-02-01     538
# 2014-03-01     848
# 2014-04-01    1309
# 2014-05-01    2899
# 2014-06-01    4124
# 2014-07-01    5634
# 2014-08-01    8340
# dtype: int64
# Claim Severity per month (head):
# TransactionMonth
# 2013-11-01    6140.350877
# 2013-12-01    6131.370703
# 2014-01-01    6140.350877
# 2014-02-01    6150.518017
# 2014-03-01    6132.870581
# 2014-04-01    6137.927924
# 2014-05-01    6158.809366
# 2014-06-01    6164.305338
# 2014-07-01    6188.540408
# 2014-08-01    6152.972053
# Name: TotalClaims, dtype: float64
# Plot saved to ..\plot images\01 Claim Frequency and Claim Severity per Month.png

# %% [markdown]
# ## *Claim by Vehicle Makes/Models*

# %%
#call function to calculate claim amounts by vehicle make and mode
eda_processor.make_model_claim()
# Out:
# Average Claim Amount by Vehicle Make (Top 10):
# Make
# SUZUKI                                 6455.408466
# POLARSUN                               6355.644715
# AUDI                                   6274.496298
# B.A.W                                  6273.557566
# IVECO                                  6244.147970
# MERCEDES-BENZ                          6239.362460
# GOLDEN JOURNEY                         6234.617347
# FIAT                                   6230.423337
# VOLKSWAGEN                             6226.208976
# MERCEDES-BENZ                          6208.545126
# Name: TotalClaims, dtype: float64
# Average Claim Amount by Vehicle Model (Top 10):
# Model
# L/CRUISER FJ 4.0 V6 CRUISER    11310.755848
# DUCATO 2.3 JTD VETRATO          7093.008152
# SPRINTER 515 CDi F/C P/V        7091.306596
# C180 BE COUPE                   7088.475183
# POLO VIVO 1.6 5Dr               6891.155373
# SPRINTER 312D F/C P/V           6711.855396
# A4 1.8T S AVANT MULTITRONIC     6678.020897
# YARIS T1 3Dr                    6631.146747
# ERTIGA 1.4 GA                   6613.518547
# SPRINTER 519 CDi F/C P/V        6549.641070
# Name: TotalClaims, dtype: float64

# %% [markdown]
# ## *Univariate Analysis*

# %%
#call function to visualise numerical and categorical columns
eda_processor.univariate_analysis_visualiser()
# Out:
# Plotting Histograms for Numerical Columns:
#
# Plot saved to ..\plot images\02 Distribution of UnderwrittenCoverID Column.png
# Plot saved to ..\plot images\02 Distribution of PolicyID Column.png
# Plot saved to ..\plot images\02 Distribution of PostalCode Column.png
# Plot saved to ..\plot images\02 Distribution of Mmcode Column.png
# Plot saved to ..\plot images\02 Distribution of Cylinders Column.png
# Plot saved to ..\plot images\02 Distribution of Cubiccapacity Column.png
# Plot saved to ..\plot images\02 Distribution of Kilowatts Column.png
# Plot saved to ..\plot images\02 Distribution of NumberOfDoors Column.png
# Plot saved to ..\plot images\02 Distribution of CapitalOutstanding Column.png
# Plot saved to ..\plot images\02 Distribution of SumInsured Column.png
# Plot saved to ..\plot images\02 Distribution of CalculatedPremiumPerTerm Column.png
# Plot saved to ..\plot images\02 Distribution of TotalPremium Column.png
# Plot saved to ..\plot images\02 Distribution of TotalClaims Column.png
# Plotting Bar Charts for Categorical Columns with more than one unique values:
#
# Plot saved to ..\plot images\03 Distribution of IsVATRegistered Column.png
# Plot saved to ..\plot images\03 Distribution of LegalType Column.png
# Plot saved to ..\plot images\03 Distribution of Title Column.png
# Plot saved to ..\plot images\03 Distribution of Bank Column.png
# Plot saved to ..\plot images\03 Distribution of AccountType Column.png
# Plot saved to ..\plot images\03 Distribution of MaritalStatus Column.png
# Plot saved to ..\plot images\03 Distribution of Gender Column.png
# Plot saved to ..\plot images\03 Distribution of Province Column.png
# Plot saved to ..\plot images\03 Distribution of MainCrestaZone Column.png
# Plot saved to ..\plot images\03 Distribution of SubCrestaZone Column.png
# Plot saved to ..\plot images\03 Distribution of VehicleType Column.png
# Plot saved to ..\plot images\03 Distribution of Bodytype Column.png
# Plot saved to ..\plot images\03 Distribution of AlarmImmobiliser Column.png
# Plot saved to ..\plot images\03 Distribution of TrackingDevice Column.png
# Plot saved to ..\plot images\03 Distribution of NewVehicle Column.png
# Plot saved to ..\plot images\03 Distribution of TermFrequency Column.png
# Plot saved to ..\plot images\03 Distribution of ExcessSelected Column.png
# Plot saved to ..\plot images\03 Distribution of CoverCategory Column.png
# Plot saved to ..\plot images\03 Distribution of CoverType Column.png
# Plot saved to ..\plot images\03 Distribution of CoverGroup Column.png
# Plot saved to ..\plot images\03 Distribution of Section Column.png
# Plot saved to ..\plot images\03 Distribution of Product Column.png

# %% [markdown]
# ## *Bivariate Analysis*

# %%
#call function to visualise corelations and association
eda_processor.bivariate_analysis_and_visualiser()
# Out:
# Monthly aggregated data by PostalCode (head):
#        Month  PostalCode  MonthlyTotalPremium  MonthlyTotalClaims
# 0 2013-11-01          84           177.909298        98245.614035
# 1 2013-11-01        1441          1831.639865       331578.947368
# 2 2013-11-01        1496          1901.030158       331578.947368
# 3 2013-11-01        1744           644.717135        98245.614035
# 4 2013-11-01        2040           128.002269        98245.614035
# Monthly changes by PostalCode (head):
#         Month  PostalCode  MonthlyTotalPremium  MonthlyTotalClaims  \
# 10 2013-12-01          84          1265.777193        98245.614035
# 11 2013-12-01        1441          2780.619386       331578.947368
# 12 2013-12-01        1496          2477.317456       331578.947368
# 14 2013-12-01        1744          1094.121053        94482.921053
# 15 2013-12-01        2040          1121.542807        98245.614035
#
#     PremiumChange  ClaimsChange
# 10    1087.867895      0.000000
# 11     948.979520      0.000000
# 12     576.287298      0.000000
# 14     449.403918  -3762.692982
# 15     993.540538      0.000000
# Plot saved to ..\plot images\04 Monthly Claims Change vs Monthly Premium Change by PostalCode.png
# Correlation Matrix for Monthly Changes (all PostalCodes):
#                PremiumChange  ClaimsChange
# PremiumChange       1.000000      0.935329
# ClaimsChange        0.935329      1.000000
# Plot saved to ..\plot images\05 Correlation Heatmap for Monthly Premium and Claims Change.png

# %% [markdown]
# ## *Data Comparison*

# %%
#call function to visualise geographic and association
eda_processor.geographic_trends_analysis_and_visualiser(plot_folder)
# Out:
# Distribution of Cover Type by Province:
#
# Plot saved to ..\plot images\06 Distribution of Insurance Cover Type by Province.png
# Average TotalPremium by Province:
# Province
# KwaZulu-Natal    78.507521
# Eastern Cape     72.609232
# Mpumalanga       71.346877
# Free State       68.579410
# Limpopo          68.235695
# Gauteng          66.006311
# Western Cape     63.094589
# North West       60.460375
# Northern Cape    47.720146
# Name: TotalPremium, dtype: float64
# Plot saved to ..\plot images\07 Average TotalPremium by Province.png
# Distribution of Top Auto Makes by Province:(head)
#
# Plot saved to ..\plot images\08 Distribution of Top Auto Makes by Province.png

# %% [markdown]
# ## *Outlier Detection*

# %%
#call function to visualise outliers
eda_processor.outlier_detection_boxplots(plot_folder)
# Out:
# Plotting Box Plots for Outlier Detection in Numerical Columns:
#
# Plot saved to ..\plot images\09 Box Plot of UnderwrittenCoverID for Outlier Detection.png
# Plot saved to ..\plot images\09 Box Plot of PolicyID for Outlier Detection.png
# Plot saved to ..\plot images\09 Box Plot of PostalCode for Outlier Detection.png
# Plot saved to ..\plot images\09 Box Plot of Mmcode for Outlier Detection.png
# Plot saved to ..\plot images\09 Box Plot of Cylinders for Outlier Detection.png
# Plot saved to ..\plot images\09 Box Plot of Cubiccapacity for Outlier Detection.png
# Plot saved to ..\plot images\09 Box Plot of Kilowatts for Outlier Detection.png
# Plot saved to ..\plot images\09 Box Plot of NumberOfDoors for Outlier Detection.png
# Plot saved to ..\plot images\09 Box Plot of CapitalOutstanding for Outlier Detection.png
# Plot saved to ..\plot images\09 Box Plot of SumInsured for Outlier Detection.png
# Plot saved to ..\plot images\09 Box Plot of CalculatedPremiumPerTerm for Outlier Detection.png
# Plot saved to ..\plot images\09 Box Plot of TotalPremium for Outlier Detection.png
# Plot saved to ..\plot images\09 Box Plot of TotalClaims for Outlier Detection.png
